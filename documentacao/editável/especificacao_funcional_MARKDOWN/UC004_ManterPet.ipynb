# %% [markdown]
# ***
#
# # CPC - Creche Pet Coragem
# ***

# %% [markdown]
# ## ESPECIFICAÇÃO FUNCIONAL
# ### UC004 - Manter Pet

# %% [markdown]
# | | | | _Controle de versões_ |
# | :------- | :------: | :------: | :------ |
# | **Nome Completo** | **Data Criação** | **Data Revisão** | **Descrição**  |
# | <small>Michelly Victoria Nonato Coelho</small> | <small> 16-10-2023</small>  | <small> 16-10-2023 </small> | <small> Criação do documento. </small>|
# |<small>Michelly Victoria Nonato Coelho <br> Paula Andrezza Gomes Marinho</small>| <small>16-09-2023</small>| <small>03-11-2023</small>|  <small>Modificação da prototipagem</small>|
# |<small>Michelly Victoria Nonato Coelho <br> Paula Andrezza Gomes Marinho</small>| <small>13-09-2023</small>| <small>03-11-2023</small>|  <small>Modificação da prototipagem</small> |
# |<small>Thabata Cristine de Lima </small>| <small>13-09-2023</small>| <small>06-12-2023</small>|  <small>Revisão do caso de uso Manter Pet</small>|| <small>Michelly Victoria Nonato Coelho</small> | <small> 16-10-2023</small>  | <small> 06-12-2023 </small> | <small> Alteração em cadastro e editar. </small>|
# | <small>Paula Andrezza Gomes Marinho<br>Michelly Victoria Nonato Coelho</small> | <small>13-09-2023</small>  | <small> 09-12-2023 </small> | <small> Inserção de Interfaces corretas e reajuste de informações, versão 2. </small> |

# %% [markdown]
# ### Descrição Resumida do Caso de Uso
# <small> Este caso de uso tem por objetivo efetuar atividades CRUD com os dados do pet. </small>

# %% [markdown]
# | | |
# | :------- | :------ |
# | **Atores** | Funcionário|
# | **Pré-Condição** | O funcionário deve estar autenticado no caso `UC001`. |
# | **Fluxo Principal** | **P01.** Na `Interface005` o funcionário irá clicar em `"Pets"` sendo direcionado a `Interface013`. <br> **P02.** O sistema irá retornar a listas de pets existente na base de dados. <br> **P03.** O funcionário poderá atualizar informações do pet, adicionar um novo pet, excluir um pet e ver o tutor do pet. <br> **P04.** O funcionário poderá cadastrar um novo pet em `"Cadastrar Pet"`, sendo direcionado a 5. <br> **P05.** O caso de uso termina. |
# | **Fluxo Alternativos** | **A01 [P02] - Pesquisar pet** <br> 1. O funcionário poderá filtrar as informações da lista pelo nome do pet, raça e espécie. <br> **A02 [P04] Cadastrar novo pet** <br>1. O funcionário clica em  `"+ Adicionar pet"` sendo direcionado para a `Interface015` retornando uma lista de tutores já cadastrados no sistema para serem vinculados ao pet.<br> 2. O funcionário seleciona o tutor a ser vinculado clicando em `"Vincular pet"`, sendo direcionado a `Interface016`. <br> 3. O funcionário preenche as informações do pet e clica em "`Cadastrar pet`", sendo direcionado a `Interface017`. <br> **A03 [P03] - Atualizar pet** <br> 1. O funcionário poderá clicar em `"Ver pet"`. <br> 2. O sistema direciona a `Interface017`. <br> 3. O funcionário modifca as informções necessárias e clica em `"Editar pet"`. <br> 4. O sistema retorna a `Interface016`.|
# | **Exceções** | Não se aplica. |
# | **Pós-Condição** | Instancia Pet atualizada ou criada.|
# | **Produtos Gerados** | Apresenta quantidade de animais ativos na empresa.|
# | **Requisitos** | O sistema deve cadastrar o animal com os seguintes dados: Imagem, Nome, Idade, Gênero, Raça, Histórico de saúde, Espécie.
# | **Regras de Negócio** | Não se aplica. |
# | **Casos de Uso Incluídos** | Não se aplica. |
# | **Casos de Uso Estendidos** |  Não se aplica. |

# %% [markdown]
# ### Protótipos de Interfaces
#
# ### Interface014 - Pets
#
# <br>
#
# ![Interface014_Pets.jpeg](attachment:Interface014_Pets.jpeg)

# %% [markdown]
# ### Interface015 - Vincular Tutor
#
# <br>
#
# ![Interface015_VincularTutor.jpeg](attachment:Interface015_VincularTutor.jpeg)

# %% [markdown]
# ### Interface016 - Cadastrar Pet
#
# <br>
#
# ![Interface016_CadastrarPet.jpeg](attachment:Interface016_CadastrarPet.jpeg)

# %% [markdown]
# ### Interface017 - Detalhes do Pet
#
# <br>
#
# ![Interface017_DetalhesPet.jpeg](attachment:Interface017_DetalhesPet.jpeg)

# %% [markdown]
# ***
# _<small> Curso Análise e Desenvolvimento de Sistemas (ADS) - Análise Orientada a Objetos (AOOI3) - 3o. módulo. <br>Modelo e formato elaborado por profa. Ana Paula Müller Giancoli - BSD 2-Clause License. - Setembro.2020.</small>_

# %% [markdown]
# <div vw class="enabled">
#     <div vw-access-button class="active"></div>
#     <div vw-plugin-wrapper>
#       <div class="vw-plugin-top-wrapper"></div>
#     </div>
# </div>
# <script src="https://vlibras.gov.br/app/vlibras-plugin.js"></script>
# <script>
#     new window.VLibras.Widget('https://vlibras.gov.br/app');
# </script>
